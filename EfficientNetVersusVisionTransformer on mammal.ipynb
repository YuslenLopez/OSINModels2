# %%
import os
from scipy.signal import spectrogram 
from scipy.io import wavfile
import numpy as np
from PIL import Image
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt

# %%
#Does not need to run each time 
#parameters for the split audio function 
input_file =r"C:\Users\yusle\OneDrive\Desktop\boat_audio\audio\noise_target数据集\noise_target数据集\noise_未切分\DATA0001\DATA0033.wav"
output_dir='NoiseFragments2'
os.makedirs(output_dir, exist_ok=True)
chunk_duration=3
startingfilenumber=100

# %%
#Does not need to run eah time 
#Function Def for turning larger audio files into smaller 3 second fragments 
import os
import numpy as np
import librosa
import soundfile as sf

def split_audio_into_chunks(input_file, output_dir, chunk_duration=3,startingfilenumber=0):
    os.makedirs(output_dir, exist_ok=True)
    
    # Load audio file
    y, sr = librosa.load(input_file, sr=None)  # keep original sample rate
    
    chunk_samples = chunk_duration * sr
    total_samples = len(y)
    
    num_chunks = total_samples // chunk_samples
    
    for i in range(num_chunks):
        start = i * chunk_samples
        end = start + chunk_samples
        chunk = y[start:end]
        
        output_path = os.path.join(output_dir, f"chunk_{startingfilenumber:04d}.wav")
        sf.write(output_path, chunk, sr)
        startingfilenumber+=1
       
    
    print(f"Saved {num_chunks} chunks to {output_dir}")

# %%
#Does not need to run each time 
#Usage for the split_audio function 
split_audio_into_chunks(input_file, output_dir, chunk_duration,startingfilenumber)
# Out:
# Saved 100 chunks to NoiseFragments2

# %%
#Does not need to run each time
#function for combining folder files into one
import os
import shutil

def combine_folders(source_folders, destination_folder, move_files=False):
    """
    Combines contents of multiple folders into a single folder.
    
    Parameters:
        source_folders (list): List of folder paths to combine
        destination_folder (str): Target folder path
        move_files (bool): If True, moves files. If False, copies files.
    """
    
    os.makedirs(destination_folder, exist_ok=True)
    
    for folder in source_folders:
        for root, _, files in os.walk(folder):
            for file in files:
                source_path = os.path.join(root, file)
                
                # Handle duplicate filenames
                base_name = file
                name, ext = os.path.splitext(base_name)
                counter = 1
                dest_path = os.path.join(destination_folder, base_name)
                
                while os.path.exists(dest_path):
                    new_name = f"{name}_{counter}{ext}"
                    dest_path = os.path.join(destination_folder, new_name)
                    counter += 1
                
                if move_files:
                    shutil.move(source_path, dest_path)
                else:
                    shutil.copy2(source_path, dest_path)

    print("Done combining folders.")

# %%
#Does not need to run each time 
#using combin_folders function
source_dirs = [
    r"C:\Users\yusle\OneDrive\Desktop\boat_audio\NoiseFragments1",
    r"C:\Users\yusle\OneDrive\Desktop\boat_audio\NoiseFragments2"
    
]

combine_folders(source_dirs, "combined_noise", move_files=False)
# Out:
# Done combining folders.

# %%
audio_folder=r'C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise'
output_folder='2_spec'
os.makedirs(output_folder, exist_ok=True)

# %%
# We need to create parmeters for the spectrogram
freq_min=10
freq_max=1000
window_size=1024
overlapp=800
n_fft=1024*4  #2^10

# %%
#loop for turning audio files in the directed folder into scectrogram with a mask and then normilzing it and saving the image to the output folder
for file in os.listdir(audio_folder):
    file_path= os.path.join(audio_folder,file)
    print(file_path)
    fs,x=wavfile.read(file_path)
    f,t,S=spectrogram(x,fs,nperseg=window_size,noverlap=overlapp,nfft=n_fft)
    f_mask=(f>=freq_min)&(f<=freq_max)
    sxx=S[f_mask,:]
    G=10*np.log10(sxx+1e-8)
    G=np.flipud(G)
    # normalize the spectrogram
    norm=Normalize(vmin=np.min(G),vmax=np.max(G))
    G_normalized=norm(G)
    # convert spectrogram to image
    G_colormap=plt.cm.jet( G_normalized)
    G_image=( G_colormap[:,:,:3]*255).astype(np.uint8)
    G_resized=Image.fromarray(G_image).resize((224,224))
    output_file=os.path.join(output_folder,os.path.basename(file_path).replace('.wav','.png'))
    G_resized.save(  output_file)
# Out:
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0000.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0001.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0002.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0003.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0004.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0005.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0006.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0007.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0008.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0009.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0010.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0011.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0012.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0013.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0014.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0015.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0016.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0017.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0018.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0019.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0020.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0021.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0022.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0023.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0024.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0025.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0026.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0027.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0028.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0029.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0030.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0031.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0032.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0033.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0034.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0035.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0036.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0037.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0038.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0039.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0040.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0041.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0042.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0043.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0044.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0045.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0046.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0047.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0048.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0049.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0050.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0051.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0052.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0053.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0054.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0055.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0056.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0057.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0058.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0059.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0060.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0061.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0062.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0063.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0064.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0065.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0066.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0067.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0068.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0069.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0070.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0071.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0072.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0073.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0074.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0075.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0076.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0077.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0078.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0079.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0080.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0081.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0082.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0083.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0084.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0085.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0086.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0087.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0088.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0089.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0090.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0091.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0092.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0093.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0094.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0095.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0096.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0097.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0098.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0099.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0100.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0101.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0102.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0103.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0104.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0105.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0106.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0107.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0108.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0109.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0110.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0111.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0112.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0113.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0114.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0115.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0116.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0117.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0118.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0119.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0120.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0121.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0122.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0123.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0124.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0125.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0126.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0127.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0128.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0129.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0130.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0131.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0132.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0133.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0134.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0135.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0136.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0137.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0138.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0139.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0140.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0141.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0142.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0143.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0144.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0145.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0146.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0147.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0148.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0149.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0150.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0151.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0152.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0153.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0154.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0155.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0156.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0157.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0158.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0159.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0160.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0161.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0162.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0163.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0164.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0165.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0166.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0167.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0168.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0169.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0170.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0171.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0172.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0173.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0174.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0175.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0176.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0177.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0178.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0179.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0180.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0181.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0182.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0183.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0184.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0185.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0186.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0187.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0188.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0189.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0190.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0191.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0192.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0193.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0194.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0195.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0196.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0197.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0198.wav
# C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\combined_noise\chunk_0199.wav

# %%
# create model for training
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
#for splitting folder with subfolder classes into folder with train and validation 70/30 split folder and each having all the subfolder classes  
import os
import shutil
import random

# ===== CONFIG =====
source_dir = r"C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\classes"   # folder with class subfolders
train_dir = r"C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\SplitClasses\Train"
test_dir = r"C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\SplitClasses\Val"
split_ratio = 0.7
random_seed = 42
# ==================

random.seed(random_seed)

# Create Train and Test directories
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Loop over each class folder
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)

    if not os.path.isdir(class_path):
        continue

    # Create class folders in Train and Test
    train_class_dir = os.path.join(train_dir, class_name)
    test_class_dir = os.path.join(test_dir, class_name)

    os.makedirs(train_class_dir, exist_ok=True)
    os.makedirs(test_class_dir, exist_ok=True)

    # Get all image files
    images = [
        f for f in os.listdir(class_path)
        if f.lower().endswith((".png", ".jpg", ".jpeg"))
    ]

    random.shuffle(images)

    split_index = int(len(images) * split_ratio)
    train_images = images[:split_index]
    test_images = images[split_index:]

    # Copy files
    for img in train_images:
        shutil.copy2(
            os.path.join(class_path, img),
            os.path.join(train_class_dir, img)
        )

    for img in test_images:
        shutil.copy2(
            os.path.join(class_path, img),
            os.path.join(test_class_dir, img)
        )

    print(f"{class_name}: {len(train_images)} train / {len(test_images)} test")

print("✅ Dataset split complete.")
# Out:
# 1_spec: 1866 train / 801 test
# 2_spec: 140 train / 60 test
# 3_spec: 4383 train / 1879 test
# 4_spec: 1400 train / 600 test
# ✅ Dataset split complete.

# %%
# prepare data
data_dir = r"C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\SplitClasses"  # Replace with your folder path
# Hyperparameters
batch_size = 32
num_epochs = 10
learning_rate = 0.001
num_classes =4  # Number of subfolders-(each folder is a class)
print(num_classes)

# Image transformations
transform = transforms.Compose([transforms.ToTensor()])
# Out:
# 4

# %%
# Load dataset
train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "Train"), transform=transform)
val_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "Val"), transform=transform)

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class ViTModel(nn.Module):
    def __init__(self, num_classes):
        super(ViTModel, self).__init__()
        # Load pretrained Vision Transformer model
        self.model = models.vit_b_16(pretrained=True)
        
        # Replace the head (classification layer)
        in_features = self.model.heads.head.in_features  # Get input features of the head
        self.model.heads.head = nn.Linear(in_features, num_classes)  # Replace with new classification layer

    def forward(self, x):
        return self.model(x)

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA GeForce RTX 3070

# %%
#declaring the efficentNetModel structure 
class EfficientNetModel(nn.Module):
    def __init__(self, num_classes):
        super(EfficientNetModel, self).__init__()
        self.model = models.efficientnet_b0(pretrained=True)
        self.model.classifier[1] = nn.Linear(self.model.classifier[1].in_features, num_classes)

    def forward(self, x):
        return self.model(x)

# %%
class EfficientNetModel(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.model = models.efficientnet_b0(pretrained=True)

        in_features = self.model.classifier[1].in_features
        self.model.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(in_features, 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(p=0.3),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        return self.model(x)

# %%
#declaring the efficentNetModel b3 structure 
class EfficientNetModel(nn.Module):
    def __init__(self, num_classes):
        super(EfficientNetModel, self).__init__()
        self.model = models.efficientnet_b3(pretrained=True)
        self.model.classifier[1] = nn.Linear(self.model.classifier[1].in_features, num_classes)

    def forward(self, x):
        return self.model(x)

# %%
# Initialize models, loss function, and optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

vit_model = ViTModel(num_classes).to(device)
efficientnet_model = EfficientNetModel(num_classes).to(device)

criterion = nn.CrossEntropyLoss()
vit_optimizer = optim.Adam(vit_model.parameters(), lr=learning_rate)
efficientnet_optimizer = optim.Adam(efficientnet_model.parameters(), lr=learning_rate)
# Out:
# cuda
# c:\Users\yusle\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\yusle\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# c:\Users\yusle\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def train_model(model, optimizer, train_loader, val_loader, num_epochs, model_name):
    maxAccuracy=80
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for inputs, labels in tqdm(train_loader, desc=f"Training {model_name} Epoch {epoch+1}/{num_epochs}"):
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)

        train_loss /= len(train_loader.dataset)

        # Validation phase
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_loss /= len(val_loader.dataset)
        accuracy = correct / total * 100

        print(f"{model_name} Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Accuracy: {accuracy:.2f}%")
        #saving best model 
        if accuracy > maxAccuracy: 
            torch.save(efficientnet_model.state_dict(), 'efficientnet_model.pth')
            maxAccuracy=accuracy
            print(f"Saved model with best accuracy of {maxAccuracy:.2f}%")

# %%
def train_model(model, optimizer, train_loader, val_loader, num_epochs, model_name, num_classes):
    max_mean_accuracy = 75.0

    for epoch in range(num_epochs):

        # ------------------ TRAIN ------------------
        model.train()
        train_loss = 0.0

        for inputs, labels in tqdm(train_loader, desc=f"Training {model_name} Epoch {epoch+1}/{num_epochs}"):
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)

        train_loss /= len(train_loader.dataset)

        # ------------------ VALIDATION ------------------
        model.eval()
        val_loss = 0.0

        correct = 0
        total = 0

        # Per-class tracking
        class_correct = torch.zeros(num_classes)
        class_total = torch.zeros(num_classes)

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)

                _, predicted = torch.max(outputs, 1)

                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                # Per-class stats
                for i in range(len(labels)):
                    label = labels[i]
                    class_total[label] += 1
                    if predicted[i] == label:
                        class_correct[label] += 1

        val_loss /= len(val_loader.dataset)
        overall_accuracy = 100 * correct / total

        # Compute per-class accuracy
        class_accuracies = 100 * class_correct / class_total.clamp(min=1)

        # Mean class accuracy (balanced accuracy)
        mean_class_accuracy = class_accuracies.mean().item()

        # ------------------ PRINT METRICS ------------------
        print(f"\n{model_name} Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}")
        print(f"Val Loss: {val_loss:.4f}")
        print(f"Overall Accuracy: {overall_accuracy:.2f}%")
        print(f"Mean Class Accuracy: {mean_class_accuracy:.2f}%")

        for i in range(num_classes):
            print(f"Class {i} Accuracy: {class_accuracies[i]:.2f}%")

        # ------------------ SAVE BEST MODEL ------------------
        if mean_class_accuracy > max_mean_accuracy:
            torch.save(model.state_dict(), f"{model_name}_best_{mean_class_accuracy:.2f}%.pth")
            max_mean_accuracy = mean_class_accuracy
            print(f"Saved best model with Mean Class Accuracy: {max_mean_accuracy:.2f}%\n")

# %%
# Train Vision Transformer
train_model(vit_model, vit_optimizer, train_loader, val_loader, num_epochs, "ViT")
# Out:
# Training ViT Epoch 1/1: 100%|██████████| 957/957 [49:41<00:00,  3.12s/it]
# ViT Epoch 1/1, Train Loss: 1.0102, Val Loss: 0.9945, Val Accuracy: 57.27%

# %%
# Train EfficientNet
train_model(efficientnet_model, efficientnet_optimizer, train_loader, val_loader, num_epochs, "EfficientNet", num_classes)
# Out:
# Training EfficientNet Epoch 1/10: 100%|██████████| 263/263 [00:34<00:00,  7.63it/s]
# EfficientNet Epoch 1/10
# Train Loss: 0.3808
# Val Loss: 0.3927
# Overall Accuracy: 78.55%
# Mean Class Accuracy: 77.14%
# Class 0 Accuracy: 46.57%
# Class 1 Accuracy: 98.36%
# Class 2 Accuracy: 92.07%
# Class 3 Accuracy: 71.56%
# Saved best model with Mean Class Accuracy: 77.14%
# Training EfficientNet Epoch 2/10: 100%|██████████| 263/263 [00:34<00:00,  7.70it/s]
# EfficientNet Epoch 2/10
# Train Loss: 0.3651
# Val Loss: 0.4475
# Overall Accuracy: 77.03%
# Mean Class Accuracy: 77.00%
# Class 0 Accuracy: 42.70%
# Class 1 Accuracy: 96.72%
# Class 2 Accuracy: 87.04%
# Class 3 Accuracy: 81.55%
# Training EfficientNet Epoch 3/10: 100%|██████████| 263/263 [00:34<00:00,  7.64it/s]
# EfficientNet Epoch 3/10
# Train Loss: 0.3830
# Val Loss: 0.4528
# Overall Accuracy: 76.07%
# Mean Class Accuracy: 75.70%
# Class 0 Accuracy: 55.81%
# Class 1 Accuracy: 95.08%
# Class 2 Accuracy: 87.04%
# Class 3 Accuracy: 64.86%
# Training EfficientNet Epoch 4/10: 100%|██████████| 263/263 [00:34<00:00,  7.53it/s]
# EfficientNet Epoch 4/10
# Train Loss: 0.3690
# Val Loss: 0.3874
# Overall Accuracy: 81.35%
# Mean Class Accuracy: 78.01%
# Class 0 Accuracy: 37.95%
# Class 1 Accuracy: 100.00%
# Class 2 Accuracy: 98.53%
# Class 3 Accuracy: 75.56%
# Saved best model with Mean Class Accuracy: 78.01%
# Training EfficientNet Epoch 5/10: 100%|██████████| 263/263 [00:35<00:00,  7.50it/s]
# EfficientNet Epoch 5/10
# Train Loss: 0.3513
# Val Loss: 0.3872
# Overall Accuracy: 79.38%
# Mean Class Accuracy: 75.83%
# Class 0 Accuracy: 52.93%
# Class 1 Accuracy: 96.72%
# Class 2 Accuracy: 96.93%
# Class 3 Accuracy: 56.76%
# Training EfficientNet Epoch 6/10: 100%|██████████| 263/263 [00:35<00:00,  7.49it/s]
# EfficientNet Epoch 6/10
# Train Loss: 0.3520
# Val Loss: 0.4149
# Overall Accuracy: 74.86%
# Mean Class Accuracy: 76.48%
# Class 0 Accuracy: 63.80%
# Class 1 Accuracy: 96.72%
# Class 2 Accuracy: 82.90%
# Class 3 Accuracy: 62.51%
# Training EfficientNet Epoch 7/10: 100%|██████████| 263/263 [00:35<00:00,  7.50it/s]
# EfficientNet Epoch 7/10
# Train Loss: 0.3530
# Val Loss: 0.4038
# Overall Accuracy: 77.74%
# Mean Class Accuracy: 78.21%
# Class 0 Accuracy: 52.43%
# Class 1 Accuracy: 95.08%
# Class 2 Accuracy: 85.52%
# Class 3 Accuracy: 79.79%
# Saved best model with Mean Class Accuracy: 78.21%
# Training EfficientNet Epoch 8/10: 100%|██████████| 263/263 [00:35<00:00,  7.48it/s]
# EfficientNet Epoch 8/10
# Train Loss: 0.3411
# Val Loss: 0.4068
# Overall Accuracy: 79.11%
# Mean Class Accuracy: 75.23%
# Class 0 Accuracy: 48.56%
# Class 1 Accuracy: 96.72%
# Class 2 Accuracy: 97.46%
# Class 3 Accuracy: 58.17%
# Training EfficientNet Epoch 9/10: 100%|██████████| 263/263 [00:35<00:00,  7.50it/s]
# EfficientNet Epoch 9/10
# Train Loss: 0.3514
# Val Loss: 0.4086
# Overall Accuracy: 80.12%
# Mean Class Accuracy: 77.20%
# Class 0 Accuracy: 40.45%
# Class 1 Accuracy: 96.72%
# Class 2 Accuracy: 95.23%
# Class 3 Accuracy: 76.38%
# Training EfficientNet Epoch 10/10: 100%|██████████| 263/263 [00:35<00:00,  7.51it/s]
# EfficientNet Epoch 10/10
# Train Loss: 0.3460
# Val Loss: 0.4298
# Overall Accuracy: 80.47%
# Mean Class Accuracy: 75.28%
# Class 0 Accuracy: 42.70%
# Class 1 Accuracy: 90.16%
# Class 2 Accuracy: 97.28%
# Class 3 Accuracy: 70.98%

# %%
# SAVE (after training)
torch.save(efficientnet_model.state_dict(), f'efficientnet_best.pth')

# %%
# Initialize models, loss function, and optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

vit_model = ViTModel(num_classes).to(device)
MyModel = EfficientNetModel(num_classes).to(device)

criterion = nn.CrossEntropyLoss()
vit_optimizer = optim.Adam(vit_model.parameters(), lr=learning_rate)
efficientnet_optimizer = optim.Adam(efficientnet_model.parameters(), lr=learning_rate)

# %%
# LOAD (in your Flask app)
model = MyModel()
model.load_state_dict(torch.load('model.pth', map_location='cpu'))
model.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 # LOAD (in your Flask app)
# ----> 2 model = MyModel()
#       3 model.load_state_dict(torch.load('model.pth', map_location='cpu'))
#       4 model.eval()
#
# NameError: name 'MyModel' is not defined

# %%
# Example single datapoint
sample = torch.randn(40)

# Add batch dimension (VERY IMPORTANT)
sample = sample.unsqueeze(0)

with torch.no_grad():
    output = model(sample)

predicted_class = torch.argmax(output, dim=1)
print("Prediction:", predicted_class.item())

# %% [markdown]
# fix code from here down

# %%
from torchvision import datasets
from torch.utils.data import DataLoader

val_dataset = datasets.ImageFolder(
    root=r"C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\SplitClasses\Val",
    transform=transform
)

val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False
)

class_names = val_dataset.classes
num_classes = len(class_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       1 from torchvision import datasets
#       2 from torch.utils.data import DataLoader
#       4 val_dataset = datasets.ImageFolder(
#       5     root=r"C:\Users\yusle\OneDrive\Desktop\Git Hub Repositories\OSINModels2\SplitClasses\Val",
# ----> 6     transform=transform
#       7 )
#       9 val_loader = DataLoader(
#      10     val_dataset,
#      11     batch_size=32,
#      12     shuffle=False
#      13 )
#      15 class_names = val_dataset.classes
#
# NameError: name 'transform' is not defined

# %%
import torch
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score

# %%
def evaluate_model(model, dataloader, device):
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in dataloader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    # Accuracy
    accuracy = accuracy_score(all_labels, all_preds)

    # Recall (macro)
    recall = recall_score(all_labels, all_preds, average="macro")

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)

    # Sensitivity & Specificity
    sensitivity = []
    specificity = []

    for i in range(len(cm)):
        TP = cm[i, i]
        FN = cm[i, :].sum() - TP
        FP = cm[:, i].sum() - TP
        TN = cm.sum() - (TP + FN + FP)

        sens = TP / (TP + FN) if (TP + FN) > 0 else 0
        spec = TN / (TN + FP) if (TN + FP) > 0 else 0

        sensitivity.append(sens)
        specificity.append(spec)

    results = {
        "accuracy": accuracy,
        "recall_macro": recall,
        "sensitivity_per_class": sensitivity,
        "specificity_per_class": specificity,
        "sensitivity_macro": np.mean(sensitivity),
        "specificity_macro": np.mean(specificity),
        "confusion_matrix": cm
    }

    return results

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

metrics = evaluate_model(model, val_loader, device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ----> 2 model.to(device)
#       4 metrics = evaluate_model(model, val_loader, device)
#
# NameError: name 'model' is not defined

# %%
print(f"Accuracy:    {metrics['accuracy']:.4f}")
print(f"Recall:      {metrics['recall_macro']:.4f}")
print(f"Sensitivity: {metrics['sensitivity_macro']:.4f}")
print(f"Specificity: {metrics['specificity_macro']:.4f}")

print("\nPer-class metrics:")
for i, class_name in enumerate(class_names):
    print(
        f"{class_name:10s} | "
        f"Sensitivity: {metrics['sensitivity_per_class'][i]:.4f} | "
        f"Specificity: {metrics['specificity_per_class'][i]:.4f}"
    )
